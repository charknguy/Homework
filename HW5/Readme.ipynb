# %%
#Observations
#1. Urban Pyber data showed that there were more Pyber drivers per city, lower fare cost per ride and more rides per city than the Suburban and Rural Pyber data.
#2. Suburban Pyber data showed that Suburban Pyber drivers fare costs were slightly higher than Urban Pyber drivers but less than Rural Pyber drivers. On average, there were less Pyber drivers and rides in suburban cities.
#3. Rural Pyber date showed that there were much less Pyber drivers and amount of rides in Rural cities. The date also showed that the ride fare in rural cities varied more than the other city types, this could be that the distance traveled between rural cities is greater than the suburban and urban cities.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ride_df = pd.read_csv('ride_data.csv')
city_df = pd.read_csv('city_data.csv')

# %%
combined_df = pd.merge(ride_df, city_df, how='outer', on='city')
combined_df
# Out:
#                       city                 date   fare        ride_id  \
# 0                 Sarabury  2016-01-16 13:49:27  38.35  5403689035038
# 1                 Sarabury  2016-07-23 07:42:44  21.76  7546681945283
# 2                 Sarabury  2016-04-02 04:32:25  38.03  4932495851866
# 3                 Sarabury  2016-06-23 05:03:41  26.82  6711035373406
# 4                 Sarabury  2016-09-30 12:48:34  30.30  6388737278232
# 5                 Sarabury  2016-08-04 00:25:52  27.20  2429366407526
# 6                 Sarabury  2016-07-25 10:44:01  17.73  4467299640441
# 7                 Sarabury  2016-06-22 16:24:01  23.94  6153395712431
# 8                 Sarabury  2016-01-27 17:46:45  16.39  8220809448298
# 9                 Sarabury  2016-04-26 11:31:30  21.80  5969441875705
# 10                Sarabury  2016-08-14 19:56:59   7.83  4979570237054
# 11                Sarabury  2016-01-06 03:02:55   5.19  9988466326333
# 12                Sarabury  2016-03-29 15:47:35  17.00  3574423871181
# 13                Sarabury  2016-11-20 11:44:23  28.47  3793266633941
# 14                Sarabury  2016-07-17 20:41:06  17.79  9661023488490
# 15                Sarabury  2016-11-06 02:23:59  19.48  7305651789766
# 16                Sarabury  2016-09-26 07:30:31  26.71  6310253827816
# 17                Sarabury  2016-06-04 20:50:52  14.19  8765571028809
# 18                Sarabury  2016-01-22 23:12:06  38.40  1176229756048
# 19                Sarabury  2016-03-29 19:07:55  20.56  7019491956393
# 20                Sarabury  2016-10-18 04:33:23  37.50  1054393799736
# 21                Sarabury  2016-09-30 20:41:18  44.32  2103508227691
# 22                Sarabury  2016-07-30 10:37:38  25.99  5233926699781
# 23                Sarabury  2016-04-01 07:15:24   6.94  1931215121299
# 24                Sarabury  2016-11-23 03:08:59  37.17  9141412183460
# 25                Sarabury  2016-10-23 02:40:28  17.23  1977978528067
# 26                Sarabury  2016-04-06 21:02:54   7.14  6096364843852
# 27               South Roy  2016-01-02 18:42:34  17.49  4036272335942
# 28               South Roy  2016-12-03 08:39:02  32.88  7098916182845
# 29               South Roy  2016-11-20 02:09:58   6.81  6512612750531
# ...                    ...                  ...    ...            ...
# 2377           East Leslie  2016-11-28 09:09:15  37.76   804829686137
# 2378           East Leslie  2016-09-08 19:19:38  30.59  8211833105097
# 2379           East Leslie  2016-03-02 22:09:34  36.61  5500269118478
# 2380           East Leslie  2016-06-22 07:45:30  34.54   684950063164
# 2381         North Whitney  2016-04-01 21:21:37  51.01   612689673941
# 2382         North Whitney  2016-04-26 09:35:48  42.09  9465134041656
# 2383         North Whitney  2016-06-24 21:09:09  50.03  9224879345166
# 2384         North Whitney  2016-06-10 18:27:03  29.25  4071225680519
# 2385         North Whitney  2016-02-21 18:20:14  42.01  3306522110065
# 2386         North Whitney  2016-11-14 10:46:11  55.07  8000095653619
# 2387         North Whitney  2016-01-24 09:14:51  24.37  7069044920500
# 2388         North Whitney  2016-03-24 10:27:00  29.72  3818227780479
# 2389         North Whitney  2016-11-11 16:24:16  22.99  3454326063039
# 2390         North Whitney  2016-01-26 01:06:41  34.92  4165974278063
# 2391         Manuelchester  2016-03-21 22:15:25  49.62  6045427401799
# 2392           Shelbyhaven  2016-05-24 15:29:59  18.11  1144791937271
# 2393           Shelbyhaven  2016-10-17 14:47:38  53.42  8515375903761
# 2394           Shelbyhaven  2016-04-21 19:22:03  37.19  5142074323359
# 2395           Shelbyhaven  2016-06-12 16:57:25  30.18  2015025942653
# 2396           Shelbyhaven  2016-07-22 05:59:01  10.64  1406024986969
# 2397           Shelbyhaven  2016-01-25 01:39:16  59.43  8088329954312
# 2398  South Elizabethmouth  2016-04-03 11:13:07  22.79  8193837300497
# 2399  South Elizabethmouth  2016-03-11 12:27:01  26.72  4943246873754
# 2400  South Elizabethmouth  2016-11-23 07:47:18  46.39  1939838068038
# 2401  South Elizabethmouth  2016-07-19 09:35:59  31.09  2959749591417
# 2402  South Elizabethmouth  2016-04-21 10:20:09  16.50  5702608059064
# 2403           Matthewside  2016-02-23 17:46:29  59.65   241191157535
# 2404           Matthewside  2016-02-23 00:43:51  40.84  8665248512368
# 2405           Matthewside  2016-05-18 02:00:30  48.67  2049161404256
# 2406           Matthewside  2016-08-08 14:02:35  24.97  2872494724827
#
#       driver_count   type
# 0               46  Urban
# 1               46  Urban
# 2               46  Urban
# 3               46  Urban
# 4               46  Urban
# 5               46  Urban
# 6               46  Urban
# 7               46  Urban
# 8               46  Urban
# 9               46  Urban
# 10              46  Urban
# 11              46  Urban
# 12              46  Urban
# 13              46  Urban
# 14              46  Urban
# 15              46  Urban
# 16              46  Urban
# 17              46  Urban
# 18              46  Urban
# 19              46  Urban
# 20              46  Urban
# 21              46  Urban
# 22              46  Urban
# 23              46  Urban
# 24              46  Urban
# 25              46  Urban
# 26              46  Urban
# 27              35  Urban
# 28              35  Urban
# 29              35  Urban
# ...            ...    ...
# 2377             9  Rural
# 2378             9  Rural
# 2379             9  Rural
# 2380             9  Rural
# 2381            10  Rural
# 2382            10  Rural
# 2383            10  Rural
# 2384            10  Rural
# 2385            10  Rural
# 2386            10  Rural
# 2387            10  Rural
# 2388            10  Rural
# 2389            10  Rural
# 2390            10  Rural
# 2391             7  Rural
# 2392             9  Rural
# 2393             9  Rural
# 2394             9  Rural
# 2395             9  Rural
# 2396             9  Rural
# 2397             9  Rural
# 2398             3  Rural
# 2399             3  Rural
# 2400             3  Rural
# 2401             3  Rural
# 2402             3  Rural
# 2403             4  Rural
# 2404             4  Rural
# 2405             4  Rural
# 2406             4  Rural
#
# [2407 rows x 6 columns]

# %%
urban = combined_df[combined_df['type'] == 'Urban']
suburban = combined_df[combined_df['type'] == 'Suburban']
rural = combined_df[combined_df['type'] == 'Rural']

# %%
urban.head()
# Out:
#        city                 date   fare        ride_id  driver_count   type
# 0  Sarabury  2016-01-16 13:49:27  38.35  5403689035038            46  Urban
# 1  Sarabury  2016-07-23 07:42:44  21.76  7546681945283            46  Urban
# 2  Sarabury  2016-04-02 04:32:25  38.03  4932495851866            46  Urban
# 3  Sarabury  2016-06-23 05:03:41  26.82  6711035373406            46  Urban
# 4  Sarabury  2016-09-30 12:48:34  30.30  6388737278232            46  Urban

# %%
urban_fare_avg = urban.groupby('city')['fare'].mean()
urban_fare_avg.head()
# Out:
# city
# Alvarezhaven    23.928710
# Alyssaberg      20.609615
# Antoniomouth    23.625000
# Aprilchester    21.981579
# Arnoldview      25.106452
# Name: fare, dtype: float64

# %%
urban_fare_avg.head()
# Out:
# city
# Alvarezhaven    23.928710
# Alyssaberg      20.609615
# Antoniomouth    23.625000
# Aprilchester    21.981579
# Arnoldview      25.106452
# Name: fare, dtype: float64

# %%
urban_fare_avg_df = pd.DataFrame({"Avg_city": urban_fare_avg})

urban_fare_avg_df.reset_index(inplace=True)

# %%
urban_fare_avg_df.head()
# Out:
#            city   Avg_city
# 0  Alvarezhaven  23.928710
# 1    Alyssaberg  20.609615
# 2  Antoniomouth  23.625000
# 3  Aprilchester  21.981579
# 4    Arnoldview  25.106452

# %%
urban_total_rides = urban.groupby('city')['ride_id'].nunique()
urban_total_rides.head()
# Out:
# city
# Alvarezhaven    31
# Alyssaberg      26
# Antoniomouth    22
# Aprilchester    19
# Arnoldview      31
# Name: ride_id, dtype: int64

# %%
urban_total_rides_df = pd.DataFrame({"Total_rides_city": urban_total_rides})

urban_total_rides_df.reset_index(inplace=True)

# %%
urban_total_rides_df.head()
# Out:
#            city  Total_rides_city
# 0  Alvarezhaven                31
# 1    Alyssaberg                26
# 2  Antoniomouth                22
# 3  Aprilchester                19
# 4    Arnoldview                31

# %%
urban_total_drivers = urban.groupby('city')['driver_count']
urban_total_drivers_drop = urban.drop_duplicates(subset=['city','driver_count'], keep='last')
urban_total_drivers_drop
# Out:
#                   city                 date   fare        ride_id  \
# 26            Sarabury  2016-04-06 21:02:54   7.14  6096364843852
# 48           South Roy  2016-05-13 04:28:42  14.85  7755858811799
# 67         Wiseborough  2016-01-21 15:43:03  18.28  9676818789300
# 93         Spencertown  2016-11-22 10:05:47   4.79  2729162668443
# 119         Nguyenbury  2016-01-27 07:00:28  22.38  7425425924510
# 144        New Jeffrey  2016-09-22 23:52:38  21.44  8763732577685
# 178      Port Johnstad  2016-11-01 20:52:15  41.09  9067296393743
# 209          Jacobfort  2016-06-04 22:31:57  37.38   906007537108
# 232        Travisville  2016-09-25 03:51:39  39.45  2448021188839
# 259         Sandymouth  2016-04-25 17:56:42  23.89  2912261745379
# 287    New Andreamouth  2016-02-22 18:51:27  11.92  5787493616752
# 309      New Christine  2016-07-16 04:10:39  22.62  2709317524893
# 339        Stewartview  2016-10-10 06:20:58  13.90  4005866140934
# 362     Rodriguezburgh  2016-03-11 11:58:09  42.88  9130331181244
# 380   West Sydneyhaven  2016-02-24 06:48:52  42.96    52775545231
# 414        Swansonbury  2016-03-24 17:14:54   7.17  2321894460533
# 437           Lisatown  2016-08-07 23:07:09  15.09  6098402365128
# 465          East Erin  2016-04-30 11:04:53   9.34  6037776836315
# 486    Port Martinberg  2016-03-29 02:03:35  16.00  2860657960977
# 513        Edwardsbury  2016-07-19 20:04:23  13.27  3571086569028
# 528        Pamelahaven  2016-04-23 09:33:27  37.55  7632486767202
# 552         Fosterside  2016-12-04 21:31:45  21.49  5128740240083
# 572        West Alexis  2016-11-06 19:02:42  29.01  4924471900019
# 601        Carrollfort  2016-10-01 04:18:59  12.76  2385786307986
# 629          New David  2016-05-25 07:40:52  24.32  7741295871755
# 660       Williamshire  2016-10-24 22:12:48  39.60  3882385067550
# 686        Torresshire  2016-09-23 14:32:48  41.20  4024780961494
# 708          New Aaron  2016-09-30 09:45:03  35.26  4769926083028
# 736         Kelseyland  2016-11-26 02:34:57  15.49  5187807155760
# 758     Lake Sarashire  2016-05-03 17:43:44  32.53  1725233941812
# ...                ...                  ...    ...            ...
# 925         Smithhaven  2016-09-03 11:34:41  13.05  2352819826103
# 946   West Jefferyfurt  2016-02-03 00:54:14   5.80  4393925880724
# 970     Zimmermanmouth  2016-10-21 04:10:04  24.69  9508846094814
# 989           Eriktown  2016-09-06 07:01:34  41.11  8990582387342
# 1008       Kellershire  2016-11-20 16:46:09  22.01  4367913867547
# 1034        Alyssaberg  2016-01-08 18:50:12  17.03  1841736403845
# 1059     Lake Jennaton  2016-09-03 07:14:23   8.89  6023947302499
# 1089       West Brandy  2016-03-23 07:35:25  38.48  1506716802765
# 1118        West Oscar  2016-10-26 13:38:35   9.57   558835210731
# 1149        Arnoldview  2016-06-08 14:23:20  33.23  2561901175214
# 1181       South Louis  2016-11-22 15:34:11  35.27  3627438789238
# 1209         Lisaville  2016-01-02 09:04:22  31.16  2386664973163
# 1229      New Maryport  2016-07-01 10:14:52  27.13   382199011501
# 1258     West Dawnfurt  2016-03-22 00:46:40  16.97  9155756590990
# 1279         Davidtown  2016-04-12 21:45:55  30.19  9023918750752
# 1310        West Peter  2016-08-25 12:03:53  41.98  8601849653888
# 1333       Russellport  2016-10-05 14:04:13  17.69  5168390301277
# 1355      East Douglas  2016-08-01 01:21:55  28.37  4589100972654
# 1376         Mooreview  2016-07-11 18:46:36  19.51  2835637288297
# 1398   Port Josephfurt  2016-09-25 04:47:07  18.85   454198708789
# 1419   South Bryanstad  2016-11-16 22:51:16  13.58  3696811450171
# 1443         Prattfurt  2016-08-05 20:08:15  32.12  4506575381521
# 1458        Vickimouth  2016-05-15 19:26:26  11.88  5271795959476
# 1489      Alvarezhaven  2016-07-04 04:28:22  33.31   306054352684
# 1509       Yolandafurt  2016-08-04 23:06:32  36.08  9895622307900
# 1533  West Brittanyton  2016-07-07 13:33:03  24.27  9330634223713
# 1554          Maryside  2016-10-01 05:58:14  11.20   763698281945
# 1576      Antoniomouth  2016-03-09 08:07:17  31.20  1712057358094
# 1597   Lake Stevenbury  2016-10-03 00:41:32  14.32  7741014139517
# 1624   Kimberlychester  2016-11-19 09:53:46  25.99   149474167977
#
#       driver_count   type
# 26              46  Urban
# 48              35  Urban
# 67              55  Urban
# 93              68  Urban
# 119              8  Urban
# 144             58  Urban
# 178             22  Urban
# 209             52  Urban
# 232             37  Urban
# 259             11  Urban
# 287             42  Urban
# 309             22  Urban
# 339             49  Urban
# 362             52  Urban
# 380             70  Urban
# 414             64  Urban
# 437             47  Urban
# 465             43  Urban
# 486             44  Urban
# 513             11  Urban
# 528             30  Urban
# 552             69  Urban
# 572             47  Urban
# 601             55  Urban
# 629             31  Urban
# 660             70  Urban
# 686             70  Urban
# 708             60  Urban
# 736             63  Urban
# 758              8  Urban
# ...            ...    ...
# 925             67  Urban
# 946             65  Urban
# 970             45  Urban
# 989             15  Urban
# 1008            51  Urban
# 1034            67  Urban
# 1059            65  Urban
# 1089            12  Urban
# 1118            11  Urban
# 1149            41  Urban
# 1181            12  Urban
# 1209            66  Urban
# 1229            26  Urban
# 1258            34  Urban
# 1279            73  Urban
# 1310            61  Urban
# 1333             9  Urban
# 1355            12  Urban
# 1376            34  Urban
# 1398            28  Urban
# 1419            73  Urban
# 1443            43  Urban
# 1458            13  Urban
# 1489            21  Urban
# 1509             7  Urban
# 1533             9  Urban
# 1554            20  Urban
# 1576            21  Urban
# 1597            63  Urban
# 1624            13  Urban
#
# [66 rows x 6 columns]

# %%
suburban_fare_avg = suburban.groupby('city')['fare'].mean()
suburban_fare_avg.head()
# Out:
# city
# Anitamouth      37.315556
# Campbellport    33.711333
# Carrollbury     36.606000
# Clarkstad       31.051667
# Conwaymouth     34.591818
# Name: fare, dtype: float64

# %%
suburban_fare_avg_df = pd.DataFrame({"Avg_city": suburban_fare_avg})

suburban_fare_avg_df.reset_index(inplace=True)

# %%
suburban_fare_avg_df.head()
# Out:
#            city   Avg_city
# 0    Anitamouth  37.315556
# 1  Campbellport  33.711333
# 2   Carrollbury  36.606000
# 3     Clarkstad  31.051667
# 4   Conwaymouth  34.591818

# %%
suburban_total_rides = suburban.groupby('city')['ride_id'].nunique()
suburban_total_rides.head()
# Out:
# city
# Anitamouth       9
# Campbellport    15
# Carrollbury     10
# Clarkstad       12
# Conwaymouth     11
# Name: ride_id, dtype: int64

# %%
suburban_total_rides_df = pd.DataFrame({"Total_rides_city": suburban_total_rides})

suburban_total_rides_df.reset_index(inplace=True)

# %%
suburban_total_rides_df.head()
# Out:
#            city  Total_rides_city
# 0    Anitamouth                 9
# 1  Campbellport                15
# 2   Carrollbury                10
# 3     Clarkstad                12
# 4   Conwaymouth                11

# %%
suburban_total_drivers = suburban.groupby('city')['driver_count']
suburban_total_drivers_drop = suburban.drop_duplicates(subset=['city','driver_count'], keep='last')
suburban_total_drivers_drop.head()
# Out:
#                   city                 date   fare        ride_id  \
# 1687        Port James  2016-01-03 16:21:55  35.59  1509231568529
# 1688        Port James  2016-01-03 16:21:55  35.59  1509231568529
# 1711  New Samanthaside  2016-10-23 19:06:23  23.06  3922898108538
# 1726   Port Alexandria  2016-10-13 21:49:40  28.77  5128376426073
# 1743       Lake Brenda  2016-11-05 00:11:09  20.57  6852219007554
#
#       driver_count      type
# 1687            15  Suburban
# 1688             3  Suburban
# 1711            16  Suburban
# 1726            27  Suburban
# 1743            24  Suburban

# %%
rural_fare_avg = rural.groupby('city')['fare'].mean()
rural_fare_avg.head()
# Out:
# city
# East Leslie       33.660909
# East Stephen      39.053000
# East Troybury     33.244286
# Erikport          30.043750
# Hernandezshire    32.002222
# Name: fare, dtype: float64

# %%
rural_fare_avg_df = pd.DataFrame({"Avg_city": rural_fare_avg})

rural_fare_avg_df.reset_index(inplace=True)

# %%
rural_fare_avg_df.head()
# Out:
#              city   Avg_city
# 0     East Leslie  33.660909
# 1    East Stephen  39.053000
# 2   East Troybury  33.244286
# 3        Erikport  30.043750
# 4  Hernandezshire  32.002222

# %%
rural_total_rides = rural.groupby('city')['ride_id'].nunique()
rural_total_rides.head()
# Out:
# city
# East Leslie       11
# East Stephen      10
# East Troybury      7
# Erikport           8
# Hernandezshire     9
# Name: ride_id, dtype: int64

# %%
rural_total_rides_df = pd.DataFrame({"Total_rides_city": rural_total_rides})

rural_total_rides_df.reset_index(inplace=True)

# %%
rural_total_rides_df.head()
# Out:
#              city  Total_rides_city
# 0     East Leslie                11
# 1    East Stephen                10
# 2   East Troybury                 7
# 3        Erikport                 8
# 4  Hernandezshire                 9

# %%
rural_total_drivers = rural.groupby('city')['driver_count']
rural_total_drivers_drop = rural.drop_duplicates(subset=['city','driver_count'], keep='last')
rural_total_drivers_drop.head()
# Out:
#               city                 date   fare        ride_id  driver_count  \
# 2285     Horneland  2016-03-25 02:05:42  20.04  5729327140644             8
# 2291     Kinghaven  2016-07-23 08:23:50  46.08  8440329717166             3
# 2295  New Johnbury  2016-08-29 02:36:06  18.83  7368222134792             6
# 2307  South Joseph  2016-09-28 07:30:55  12.55  4336212615821             3
# 2317  Kennethburgh  2016-06-07 11:43:43  56.02   311733202150             3
#
#        type
# 2285  Rural
# 2291  Rural
# 2295  Rural
# 2307  Rural
# 2317  Rural

# %%
plt.figure(figsize=(10,10))

# %%
urban_plot = plt.scatter(urban_total_rides_df['Total_rides_city'], urban_fare_avg_df['Avg_city'], marker="o", facecolors="gold", edgecolors="black",
            s=urban_total_drivers_drop['driver_count'], alpha=0.75)
suburban_plot = plt.scatter(suburban_total_rides_df['Total_rides_city'], suburban_fare_avg_df['Avg_city'], marker="o", facecolors="lightskyblue", edgecolors="black",
            s=suburban_total_drivers_drop['driver_count'], alpha=0.75)
rural_plot = plt.scatter(rural_total_rides_df['Total_rides_city'], rural_fare_avg_df['Avg_city'], marker="o", facecolors="red", edgecolors="black",
            s=rural_total_drivers_drop['driver_count'], alpha=0.75)

# %%
plt.title("Average Ride Fares v Ride Count")
plt.xlabel("Ride Count")
plt.ylabel("Average Ride fare (Dollars)")

# %%
urban_handle, = plt.scatter(urban_total_rides_df['Total_rides_city'], urban_fare_avg_df['Avg_city'], marker="o", facecolors="gold", edgecolors="black",
            s=urban_total_drivers_drop['driver_count'], alpha=0.75)
suburban_handle, = plt.scatter(suburban_total_rides_df['Total_rides_city'], suburban_fare_avg_df['Avg_city'], marker="o", facecolors="lightskyblue", edgecolors="black",
            s=suburban_total_drivers_drop['driver_count'], alpha=0.75)
rural_handle, = plt.scatter(rural_total_rides_df['Total_rides_city'], rural_fare_avg_df['Avg_city'], marker="o", facecolors="lightcoral", edgecolors="black",
            s=rural_total_drivers_drop['driver_count'], alpha=0.75)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-0c42f98fbe00> in <module>()
#       1 urban_handle, = plt.scatter(urban_total_rides_df['Total_rides_city'], urban_fare_avg_df['Avg_city'], marker="o", facecolors="gold", edgecolors="black",
# ----> 2             s=urban_total_drivers_drop['driver_count'], alpha=0.75)
#       3 suburban_handle, = plt.scatter(suburban_total_rides_df['Total_rides_city'], suburban_fare_avg_df['Avg_city'], marker="o", facecolors="lightskyblue", edgecolors="black",
#       4             s=suburban_total_drivers_drop['driver_count'], alpha=0.75)
#       5 rural_handle, = plt.scatter(rural_total_rides_df['Total_rides_city'], rural_fare_avg_df['Avg_city'], marker="o", facecolors="lightcoral", edgecolors="black",
#
# TypeError: 'PathCollection' object is not iterable

# %%
plt.legend(handles=[urban_handle, suburban_handle, rural_handle], loc="topright")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-103-0bf588767272> in <module>()
# ----> 1 plt.legend(handles=[urban_handle, suburban_handle, rural_handle], loc="topright")
#
# NameError: name 'urban_handle' is not defined

# %%
plt.show()

# %%
urban_fare_total = urban['fare'].sum()
urban_fare_total
# Out:
# 40078.33999999997

# %%
suburban_fare_total = suburban['fare'].sum()
suburban_fare_total
# Out:
# 20335.690000000006

# %%
rural_fare_total = rural['fare'].sum()
rural_fare_total
# Out:
# 4255.090000000002

# %%
fare_type = ["urban", "suburban", "rural"]
fare_totals = [40078.33, 20335.69, 4255.09]
colors = ["gold", "lightskyblue", "lightcoral"]
explode = (0.05, 0, 0)

# %%
plt.title("% of Total Fares by City Type")
plt.pie(fare_totals, explode=explode, labels=fare_type, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=90)
plt.axis("equal")
plt.show()

# %%
urban_ride_total = urban['ride_id'].nunique()
urban_ride_total
# Out:
# 1625

# %%
suburban_ride_total = suburban['ride_id'].nunique()
suburban_ride_total
# Out:
# 625

# %%
rural_ride_total = rural['ride_id'].nunique()
rural_ride_total
# Out:
# 125

# %%
ride_type = ["urban", "suburban", "rural"]
ride_totals = [1635, 625, 125]
colors = ["gold", "lightskyblue", "lightcoral"]
explode = (0.05, 0, 0)

# %%
plt.title("% of Total Rides by City Type")
plt.pie(ride_totals, explode=explode, labels=ride_type, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=180)
plt.axis("equal")
plt.show()

# %%
urban_total_drivers = urban.groupby('city')['driver_count']
urban_total_drivers_drop = urban.drop_duplicates(subset=['city','driver_count'], keep='last')
urban_total_drivers_sum = urban_total_drivers_drop['driver_count'].sum()
urban_total_drivers_sum
# Out:
# 2607

# %%
suburban_total_drivers = suburban.groupby('city')['driver_count']
suburban_total_drivers_drop = suburban.drop_duplicates(subset=['city','driver_count'], keep='last')
suburban_total_drivers_sum = suburban_total_drivers_drop['driver_count'].sum()
suburban_total_drivers_sum
# Out:
# 638

# %%
rural_total_drivers = rural.groupby('city')['driver_count']
rural_total_drivers_drop = rural.drop_duplicates(subset=['city','driver_count'], keep='last')
rural_total_drivers_sum = rural_total_drivers_drop['driver_count'].sum()
rural_total_drivers_sum
# Out:
# 104

# %%
ride_type = ["urban", "suburban", "rural"]
ride_totals = [2607, 638, 104]
colors = ["gold", "lightskyblue", "lightcoral"]
explode = (0.05, 0, 0)

# %%
plt.title("% of Total Rides by City Type")
plt.pie(ride_totals, explode=explode, labels=ride_type, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=180)
plt.axis("equal")
plt.show()
